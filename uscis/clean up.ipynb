# %% [markdown]
# https://www.uscis.gov/tools/reports-studies/immigration-forms-data/data-set-form-i-485-application-adjustment-status

# %%
import os, time, re
import collections
import pandas as pd
import numpy as np

# %%
input_dir = os.path.join(os.getcwd(),'input')

# %%
os.path.exists(input_dir) or os.mkdir(input_dir)
# Out:
# True

# %%
pd.set_option('display.max_columns', 500)

# %%
ex = pd.read_csv(os.path.join(input_dir,'fy2018_qtr1.csv'))

# %%
# drop columns between location (first 3 columns) and total numbers (last four colums)
ex1 = ex.iloc[:,0:3].join(ex.iloc[:,-4:])

# %%
def clean_up(df):
    """
    Sets clean columns and deletes unwanted rows
    """
    #set dict of clean columns
    clean_columns = collections.OrderedDict((
        (df.columns[0], 'state'),
        (df.columns[1], 'city'),
        (df.columns[2], 'office_code'), 
        (df.columns[3], 'app_received'),
        (df.columns[4], 'app_approved'),
        (df.columns[5], 'app_denied'),
        (df.columns[6], 'app_pending'),
    ))
    
    #apply it to columns 
    df.rename(columns=clean_columns,inplace=True)
    
    #drop first rows that we are not using 
    df.drop([0], inplace=True)
    
    #drop rows that repeat the lable (first of second and third pages)
    df.dropna(subset=['state','city','office_code'], how='all', inplace=True)
    
    #fill out the state column
    df.loc[:,'state'].fillna(method='ffill', inplace=True)
    
    #strip white spaces 
    df = df.apply(lambda x: x.str.strip())
    
    #fill out all the empty strings
    df.replace('', np.nan, inplace=True)
    
    #drop where last four columns are null
    df.dropna(subset=['app_received','app_approved','app_denied','app_pending'], how='all', inplace=True)
    
    
    return df

# %%
ex2 = clean_up(ex1)

# %%
ex2
# Out:
#                     state                       city office_code app_received  \
# 4                   Total                        NaN         NaN      180,562
# 8                 Alabama                 Montgomery         MGA          664
# 10                 Alaska                  Anchorage         ANC          111
# 12                Arizona                    Phoenix         PHO        1,447
# 13                Arizona                     Tucson         TUC          409
# 15               Arkansas                 Fort Smith         FSA          169
# 17             California                Chula Vista         CVC            -
# 18             California                     Fresno         FRE          902
# 19             California                   Imperial         IMP           83
# 20             California                Los Angeles         LOS        2,318
# 21             California         Los Angeles County         LAC        2,096
# 22             California                 Sacramento         SAC          988
# 23             California             San Bernardino         SBD        1,930
# 24             California                  San Diego         SND        1,393
# 25             California        San Fernando Valley         SFV        1,462
# 26             California              San Francisco         SFR        2,287
# 27             California                   San Jose         SNJ        1,283
# 28             California                  Santa Ana         SAA        1,674
# 30               Colorado                     Denver         DEN        1,314
# 32            Connecticut                   Hartford         HAR        1,028
# 34               Delaware                      Dover         DVD            -
# 36   District of Columbia                 Washington         WAS        1,577
# 38                Florida                    Hialeah         HIA        4,208
# 39                Florida               Jacksonville         JAC          654
# 40                Florida                    Kendall         KND        4,556
# 41                Florida                      Miami         MIA        3,536
# 42                Florida                 Fort Myers         OFM        1,281
# 43                Florida               Oakland Park         OKL        1,907
# 44                Florida                    Orlando         ORL        1,971
# 45                Florida                      Tampa         TAM        2,573
# ..                    ...                        ...         ...          ...
# 114                Oregon                   Portland         POO          857
# 116          Pennsylvania               Philadelphia         PHI        1,821
# 117          Pennsylvania                 Pittsburgh         PIT          345
# 119          Rhode Island                 Providence         PRO          313
# 121        South Carolina                 Charleston         CHL          376
# 122        South Carolina                      Greer         GRR          213
# 128             Tennessee                    Memphis         MEM          892
# 130                 Texas                     Dallas         DAL        3,645
# 131                 Texas                    El Paso         ELP          904
# 132                 Texas                  Harlingen         HLG          711
# 133                 Texas                    Houston         HOU        5,025
# 134                 Texas                San Antonio         SNA        2,343
# 136                  Utah             Salt Lake City         SLC          758
# 138               Vermont                 St. Albans         STA           63
# 140              Virginia                    Norfolk         NOR          544
# 142            Washington                    Seattle         SEA        1,307
# 143            Washington                    Spokane         SPO           96
# 144            Washington                     Yakima         YAK          179
# 146         West Virginia                 Charleston         CHS            -
# 148             Wisconsin                  Milwaukee         MIL          493
# 150                  Guam                      Agana         AGA          172
# 152   U.S. Virgin Islands           Charlotte Amalie         CHA           16
# 153   U.S. Virgin Islands              Christiansted         CHR            D
# 155           Puerto Rico                   San Juan         SAJ          142
# 157        Service Center                 California         WSC        1,146
# 158        Service Center  National Benefits  Center         NBC            -
# 159        Service Center                   Nebraska         NSC       47,801
# 160        Service Center                    Potomac         YSC            -
# 161        Service Center                      Texas         SSC       17,654
# 162        Service Center                    Vermont         ESC       10,087
#
#     app_approved app_denied app_pending
# 4        142,782     12,052     650,479
# 8            225         31       2,950
# 10            99         17         319
# 12           888        131       5,866
# 13           731         33       1,250
# 15           345         25         661
# 17             -          -           -
# 18           814         88       3,090
# 19           123          D         249
# 20         2,022        167       7,677
# 21         1,546        313       9,401
# 22           862         75       3,683
# 23         1,874        228       5,350
# 24         2,285        155       4,096
# 25         1,073        152       6,193
# 26         1,860        110      11,322
# 27         1,479        101       6,368
# 28         1,126        184       7,535
# 30           618        143       6,100
# 32           489        150       3,816
# 34             -          -           -
# 36         1,429        213       7,847
# 38         2,684        143      13,384
# 39           813         66       2,204
# 40         2,139        154      12,945
# 41         1,883        177      15,126
# 42           597         49       4,612
# 43         1,048        194      10,338
# 44         1,580        196       8,086
# 45         2,840        230       7,938
# ..           ...        ...         ...
# 114          963         63       2,548
# 116        1,238        219       7,272
# 117          381         19       1,079
# 119          610         58       1,002
# 121          575         52       1,102
# 122          218          D         595
# 128          831         68       3,555
# 130        2,972        312      17,286
# 131        1,241        137       2,965
# 132          598         73       3,307
# 133        4,346        379      24,927
# 134        1,883        119       9,277
# 136          423         53       2,889
# 138          167         16         219
# 140          644         60       2,091
# 142        1,052        107       6,642
# 143          107         20         306
# 144          244         25         539
# 146            -          -           -
# 148          515         50       1,939
# 150          143         12         492
# 152            -          -         418
# 153            -          D          56
# 155          177         13         709
# 157          368         16       2,554
# 158            -          -           -
# 159       35,916      1,475     126,076
# 160            -          -           -
# 161       13,528        799      64,041
# 162        3,670        547      29,225
#
# [98 rows x 7 columns]
